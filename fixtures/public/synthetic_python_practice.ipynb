# %% [markdown]
# # UniBot public synthetic Python practice
#
# Task: inspect the list and compute its mean. Before changing code, describe the smallest check you would make.
#
# This notebook is synthetic and contains no learner, course, health, or examination data.

# %%
values = [2, 4, 6]
# Own attempt: I first inspect the input and the denominator.
mean = sum(values) / len(value)
mean
